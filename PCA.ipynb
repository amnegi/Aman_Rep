# %% [markdown]
# # PCA

# %% [markdown]
# **PCA follows the fit/transform pattern**
#
# The fit method learns how to shift and how to rotate the samples, but doesn't actually change them.
#
# The transform method, on the other hand, applies the transformation that fit learned.
#
# In particular, the transform method can be applied to new, unseen samples

# %%
import pandas as pd
df=pd.read_csv('seed.csv')
df
# Out:
#      3.312  5.763
# 0    3.333  5.554
# 1    3.337  5.291
# 2    3.379  5.324
# 3    3.562  5.658
# 4    3.312  5.386
# ..     ...    ...
# 204  2.981  5.137
# 205  2.795  5.140
# 206  3.232  5.236
# 207  2.836  5.175
# 208  2.974  5.243
#
# [209 rows x 2 columns]

# %%
#standarDiztion process: using standard scaler
#scikit learn prime package: machine learning: sklearn
from sklearn.preprocessing import StandardScaler

#instantiate the standard scaler: create an instance
scaler = StandardScaler(copy=True, with_mean=True, with_std=True)

#fittng the scaler on data
#scaler.fit(df)#algo will apply all the required maths; mean and stdev of each variable

#samples_scaled = scaler.transform(df)
#result of the scaler is always in array form

samples_scaled = scaler.fit_transform(df)
print(samples_scaled)
print()
print(df)
# Out:
# [[ 1.97647469e-01 -1.66807514e-01]
#  [ 2.08237988e-01 -7.60533387e-01]
#  [ 3.19438442e-01 -6.86035463e-01]
#  [ 8.03954705e-01  6.79738191e-02]
#  [ 1.42047242e-01 -5.46069669e-01]
#  [ 1.72285962e-03 -1.46489899e-01]
#  [ 1.15570943e-01 -4.69314233e-01]
#  [ 5.47134609e-01  9.59691384e-01]
#  [ 6.53039804e-01  5.78171717e-01]
#  [-4.32868479e-02  1.94394537e-01]
#  [-1.51839672e-01 -4.28679002e-01]
#  [-1.57134932e-01 -4.26421489e-01]
#  [-2.70983015e-01 -3.36120976e-01]
#  [-3.82183469e-01 -3.29348438e-01]
#  [ 1.97647469e-01 -6.25082617e-01]
#  [ 3.30028961e-01 -1.14882559e+00]
#  [ 6.76868472e-01 -2.27760361e-01]
#  [ 5.49782239e-01 -9.54679489e-01]
#  [-5.54279410e-01 -9.07271720e-01]
#  [-3.42469021e-01  6.79738191e-02]
#  [-2.39211457e-01 -2.43562950e-01]
#  [ 6.58335063e-01 -2.23266938e-02]
#  [-8.53461583e-01 -1.19397585e+00]
#  [-3.53439583e-02  3.63707999e-01]
#  [ 4.30638896e-01  4.63038563e-01]
#  [-6.15174896e-01 -5.25752053e-01]
#  [-8.00508986e-01 -5.25752053e-01]
# ...

# %%
# Import PCA
from sklearn.decomposition import PCA

# Create PCA instance: model
model = PCA() #all pcs will be used

# Apply the fit_transform method of model to grains: pca_features
pca_features = model.fit_transform(samples_scaled)

#principal components or PCA features
pca_features
# Out:
# array([[ 2.18071408e-02, -2.57708590e-01],
#        [-3.90531821e-01, -6.85024809e-01],
#        [-2.59223240e-01, -7.10977417e-01],
#        [ 6.16546572e-01, -5.20417075e-01],
#        [-2.85686998e-01, -4.86572134e-01],
#        [-1.02365755e-01, -1.04802247e-01],
#        [-2.50134279e-01, -4.13576274e-01],
#        [ 1.06548688e+00,  2.91721693e-01],
#        [ 8.70598015e-01, -5.29397317e-02],
#        [ 1.06849272e-01,  1.68066119e-01],
#        [-4.10488691e-01, -1.95754967e-01],
#        [-4.12636702e-01, -1.90414351e-01],
#        [-4.29287349e-01, -4.60594938e-02],
#        [-5.03129036e-01,  3.73600091e-02],
#        [-3.02242292e-01, -5.81758023e-01],
#        [-5.78976650e-01, -1.04570808e+00],
#        [ 3.17567391e-01, -6.39669182e-01],
#        [-2.86305591e-01, -1.06381509e+00],
#        [-1.03347271e+00, -2.49603256e-01],
#        [-1.94097419e-01,  2.90226916e-01],
#        [-3.41373057e-01, -3.07697045e-03],
#        [ 4.49725831e-01, -4.81300544e-01],
# ...

# %% [markdown]
# **When PCA is implemented, it leads to decorrelation of data**

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Assign 0th column of pca_features: xs
pc1 = pca_features[:,0]

# Assign 1st column of pca_features: ys
pc2 = pca_features[:,1]

# Scatter plot xs vs ys
plt.scatter(pc1, pc2)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation of xs and ys
correlation, pvalue = pearsonr(pc1, pc2)

# Display the correlation
print(correlation)
# Out:
# 6.938893903907228e-16

# %% [markdown]
# ***NO correlation.***

# %% [markdown]
# **TO demostrate how PCA is super intelligent to detect the correlations and patterns in high dimensional data, we are considering a seeds.csv**
#
# This file consists of 7 columns where each column or feature relates to some of the physical characteristic of the underlying seed variety.

# %%
import pandas as pd
grainsnew=pd.read_csv('seeds.csv')
grainsnew
# Out:
#          A      B       C      D      E      F      G
# 0    15.26  14.84  0.8710  5.763  3.312  2.221  5.220
# 1    14.88  14.57  0.8811  5.554  3.333  1.018  4.956
# 2    14.29  14.09  0.9050  5.291  3.337  2.699  4.825
# 3    13.84  13.94  0.8955  5.324  3.379  2.259  4.805
# 4    16.14  14.99  0.9034  5.658  3.562  1.355  5.175
# ..     ...    ...     ...    ...    ...    ...    ...
# 205  12.19  13.20  0.8783  5.137  2.981  3.631  4.870
# 206  11.23  12.88  0.8511  5.140  2.795  4.325  5.003
# 207  13.20  13.66  0.8883  5.236  3.232  8.315  5.056
# 208  11.84  13.21  0.8521  5.175  2.836  3.598  5.044
# 209  12.30  13.34  0.8684  5.243  2.974  5.637  5.063
#
# [210 rows x 7 columns]

# %%
#standarDiztion process: using standard scaler
#scikit learn prime package: machine learning: sklearn
from sklearn.preprocessing import StandardScaler

#instantiate the standard scaler: create an instance
scaler = StandardScaler(copy=True, with_mean=True, with_std=True)

#fittng the scaler on data
#scaler.fit(df)#algo will apply all the required maths; mean and stdev of each variable

#samples_scaled = scaler.transform(df)
#result of the scaler is always in array form

grains = scaler.fit_transform(grainsnew)

# %%
#running PCA on grains data
#pca will analyse data in high dimension
from sklearn.decomposition import PCA

pca = PCA()#instance of PCA created

projected = pca.fit_transform(grains)#7inputcolumns
#pca features

print(grains.shape)#original dataframe
print()
print(projected.shape)#PCA features/components
# Out:
# (210, 7)
#
# (210, 7)

# %%
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Assign 0th column of pca_features: xs
pc1 = projected[:,0]

# Assign 1st column of pca_features: ys
pc3 = projected[:,2]

# Scatter plot xs vs ys
plt.scatter(pc1, pc3)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation of xs and ys
correlation, pvalue = pearsonr(pc1, pc3)

# Display the correlation
print(correlation)
# Out:
# -3.8163916471489756e-17

# %% [markdown]
# When PCA converts each input column into a principal component, then it sorts the PCs into the sorted i.e. descending order. This sort is performed in terms of variation explained i,e, which component is explaining maximum variance or variation in the input data. AT any stage, target variable is not considered.
#
# TO understand the significance of a variable in terms of its contribution to the target variable.
#
# The draback is, I dont know which PC is representing which input column
#
# No predefined method to do the reverse enginnering
#
# We dont need to do that. The idea of PCA is to do dimension reduction and it is recommended in those algos which use the distance metric logic.

# %%
import numpy as np
np.round(pca.explained_variance_ratio_ * 100,1)
# Out:
# array([71.9, 17.1,  9.7,  1. ,  0.3,  0.1,  0. ])

# %%
#extract the amount of explained variation by each principal component
import numpy as np

print(np.round(pca.explained_variance_ratio_ * 100, 1))
# Out:
# [71.9 17.1  9.7  1.   0.3  0.1  0. ]

# %%
pcanew = PCA(n_components=3)#reinstantiating PCA with significant components only

grainsnew = pcanew.fit_transform(grains)#original data is grains consisting of 7 features

grainsnew.shape#only top 2 components have been produced
# Out:
# (210, 3)

# %%
grainsnew
# Out:
# array([[ 3.17047052e-01, -7.83669015e-01, -6.31010011e-01],
#        [-3.38617773e-03, -1.91321367e+00, -6.69754458e-01],
#        [-4.59443341e-01, -1.90722525e+00,  9.32488818e-01],
#        [-5.91935651e-01, -1.93106922e+00,  4.99310922e-01],
#        [ 1.10291005e+00, -2.06809003e+00,  5.67054118e-02],
#        [-3.36815150e-01, -1.63691626e+00,  4.38913151e-01],
#        [-1.45602498e-01, -4.36414570e-01,  3.01945052e-01],
#        [-4.25439933e-01, -1.39015330e+00,  4.01288373e-01],
#        [ 1.76718434e+00, -3.07528830e-01, -9.68165725e-01],
#        [ 1.44119415e+00, -1.01106830e+00, -3.83042144e-01],
#        [ 6.71107449e-02,  4.29312461e-01,  3.25292810e-01],
#        [-5.72683493e-01, -1.55824408e+00, -4.21773063e-01],
#        [-9.31414541e-01, -8.73925640e-01,  9.48782466e-01],
#        [-9.14882766e-01, -8.71940034e-01,  1.35349927e-01],
#        [-1.00836149e+00, -9.58530316e-01, -2.09395370e-03],
#        [-5.15522337e-01, -1.05872649e+00,  1.43548717e+00],
# ...

# %%
#########################
#
# Draw a scree plot and a PCA plot
#
#########################
import numpy as np
import matplotlib.pyplot as plt

#extract the variance values of each PC: explained_variance_ratio_ * 100

#The following code constructs the Scree plot
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)#result in array form
#percentage of variation that each principal component accounts for

labels = ['PC' + str(x) for x in range(1, 8)] #PC1 range(1,8): 1,2,3,4,5,6,7
#creating labels : one label per principal component

plt.bar(x=range(1,8), height=per_var, tick_label=labels)

plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %%
pca = PCA(n_components=3)

#feature selection: distance metric algos

#reduces the possibilities of overfitting
